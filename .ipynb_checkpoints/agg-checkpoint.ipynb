# %% [markdown]
# # Under Lock and Key

# %% [markdown]
# You and Harold have developed a Python application that will extract historical stock data from **Quandl** for a given ticker and calculate the Sharpe ratio for that stock. So far, only you two have been using the program, but your manager now wants you to open the application up to the entire team. You know that Quandl allows API calls to be submitted without an API key, but the limit is 50 calls a day. Quandl is diligent in their rate-limiting and keeps services under lock and key.
#
# ## Instructions
#
# ### Import the Python `requests`, `os`, and `dotenv` libraries

# %%
import pandas as pd
import requests
import dotenv
import os
import json
from pathlib import Path
import numpy
# %matplotlib inline
from datetime import datetime
import dateutil.parser

# %% [markdown]
# ### Use the `load_dotenv()` method from the `dotenv` package to load and export the environment variables

# %%
dotenv.load_dotenv()
# Out:
# True

# %% [markdown]
# ### Use the `os.getenv` function to retrieve the environment variable named `QUANDL_API_KEY`. Store as a Python variable named `api_key`

# %%
api_key = os.getenv("MARKETSTACK_API_KEY")
api_key_string = "&access_key=" + api_key 
api_key_string
# Out:
# '&access_key=aeb304d9bd929d7fe58b03e6e6852412'

# %% [markdown]
# ### Concatenate `request_url` with the `api_key` variable

# %%
dotenv.load_dotenv(dotenv.find_dotenv())
# Out:
# True

# %%
request_url = "https://api.marketstack.com/v1/exchanges/INDX/tickers?"
#request_url = "https://api.marketstack.com/v1/eod?symbols=GSPC.INDX"
request_url = request_url + api_key_string + "&limit=3000" #&sort=DESC&date_from=YYYY-MM-DD&date_to=YYYY-MM-DD&offset=0
request_url
# Out:
# 'https://api.marketstack.com/v1/exchanges/INDX/tickers?&access_key=aeb304d9bd929d7fe58b03e6e6852412&limit=3000'

# %% [markdown]
# ### Execute GET request with API key

# %%
# Execute get request
response_data = requests.get(request_url)

# %% [markdown]
# ### Display content to screen using the content attribute

# %%
# Output data
data = response_data.json()
#print(json.dumps(data, indent=4))
sp_list = data["data"]
sp_list
# Out:
# {'name': 'INDEX',
#  'mic': 'INDX',
#  'indexes': [{'name': 'AEX Amsterdam Index',
#    'symbol': 'AEX.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Netherlands',
#    'currency': {'code': 'EUR', 'symbol': '€', 'name': 'Euro'}},
#   {'name': 'Austrian Traded Index in EUR',
#    'symbol': 'ATX.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Austria',
#    'currency': {'code': 'EUR', 'symbol': '€', 'name': 'Euro'}},
#   {'name': 'S&P/ASX 200',
#    'symbol': 'AXJO.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Australia',
#    'currency': {'code': 'AUD', 'symbol': 'A$', 'name': 'Australian Dollar'}},
#   {'name': 'BEL-20 INDEX',
#    'symbol': 'BEL20.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Belgium',
#    'currency': {'code': 'EUR', 'symbol': '€', 'name': 'Euro'}},
#   {'name': 'BSE Sensex 30',
#    'symbol': 'BSESN.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'India',
#    'currency': {'code': 'INR', 'symbol': 'Rs', 'name': 'Indian Rupee'}},
#   {'name': 'Bovespa',
#    'symbol': 'BVSP.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Brazil',
#    'currency': {'code': 'BRL', 'symbol': 'R$', 'name': 'Brazilian Real'}},
#   {'name': 'DAX Composite Index',
#    'symbol': 'CDAXX.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Germany',
#    'currency': {'code': 'EUR', 'symbol': '€', 'name': 'Euro'}},
#   {'name': 'Dow Jones Composite Average',
#    'symbol': 'DJA.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'Dow Jones Industrial Average',
#    'symbol': 'DJI.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'Dow Jones Transportation',
#    'symbol': 'DJT.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'Dow Jones US',
#    'symbol': 'DJUS.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'US Dollar Index',
#    'symbol': 'DXY.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'S&P 500 Futures',
#    'symbol': 'ES.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Unknown',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'CAC 40',
#    'symbol': 'FCHI.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'France',
#    'currency': {'code': 'EUR', 'symbol': '€', 'name': 'Euro'}},
#   {'name': 'FTSE 100 Index (UK)',
#    'symbol': 'FTSE.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'UK',
#    'currency': {'code': 'GBP',
#     'symbol': '£',
#     'name': 'British Pound Sterling'}},
#   {'name': 'DAX Index',
#    'symbol': 'GDAXI.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Germany',
#    'currency': {'code': 'EUR', 'symbol': '€', 'name': 'Euro'}},
#   {'name': 'The Global Dow USD',
#    'symbol': 'GDOW.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Unknown',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'S&P 500',
#    'symbol': 'GSPC.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'S&P TSX Composite Index (Canada)',
#    'symbol': 'GSPTSE.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Canada',
#    'currency': {'code': 'CAD', 'symbol': 'CA$', 'name': 'Canadian Dollar'}},
#   {'name': 'Hang Seng China Enterprise (CEI)',
#    'symbol': 'HSCE.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Hong Kong',
#    'currency': {'code': 'HKD', 'symbol': 'HK$', 'name': 'Hong Kong Dollar'}},
#   {'name': 'Hang Seng Composite Index',
#    'symbol': 'HSCI.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Unknown',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'Hang Seng Index (Hong Kong)',
#    'symbol': 'HSI.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Hong Kong',
#    'currency': {'code': 'HKD', 'symbol': 'HK$', 'name': 'Hong Kong Dollar'}},
#   {'name': 'IBEX 35 Index',
#    'symbol': 'IBEX.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Spain',
#    'currency': {'code': 'EUR', 'symbol': '€', 'name': 'Euro'}},
#   {'name': 'MOEX Russia Index',
#    'symbol': 'IMOEX.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Russia',
#    'currency': {'code': 'RUB', 'symbol': 'RUB', 'name': 'Russian Ruble'}},
#   {'name': 'NASDAQ Composite',
#    'symbol': 'IXIC.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'KOSPI',
#    'symbol': 'KS11.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Korea',
#    'currency': {'code': 'KRW', 'symbol': '₩', 'name': 'South Korean Won'}},
#   {'name': 'S&P Midcap 400',
#    'symbol': 'MID.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'DAX Midcap Price',
#    'symbol': 'MKDX.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Unknown',
#    'currency': {'code': 'EUR', 'symbol': '€', 'name': 'Euro'}},
#   {'name': 'EuroNext 100',
#    'symbol': 'N100.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Unknown',
#    'currency': {'code': 'EUR', 'symbol': '€', 'name': 'Euro'}},
#   {'name': 'Nikkei 225 Index',
#    'symbol': 'N225.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Japan',
#    'currency': {'code': 'JPY', 'symbol': '¥', 'name': 'Japanese Yen'}},
#   {'name': 'Nasdaq 100',
#    'symbol': 'NDX.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'Nifty 50',
#    'symbol': 'NSEI.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'India',
#    'currency': {'code': 'INR', 'symbol': 'Rs', 'name': 'Indian Rupee'}},
#   {'name': 'NYSE US 100  Index',
#    'symbol': 'NY.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'NYSE Composite',
#    'symbol': 'NYA.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'NYSE Composite Total Return',
#    'symbol': 'NYATR.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'NYSE International 100 Index',
#    'symbol': 'NYI.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'NYSE World Leaders  Index',
#    'symbol': 'NYL.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'NEW ZEALAND EXCH NZSX 50 FREE IDX',
#    'symbol': 'NZ50.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'New Zealand',
#    'currency': {'code': 'NZD', 'symbol': 'NZ$', 'name': 'New Zealand Dollar'}},
#   {'name': 'S&P 100',
#    'symbol': 'OEX.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'OMXS 30 Index',
#    'symbol': 'OMX.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Sweden',
#    'currency': {'code': 'SEK', 'symbol': 'Skr', 'name': 'Swedish Krona'}},
#   {'name': 'OMX Copenhagen 25 Index',
#    'symbol': 'OMXC25.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Denmark',
#    'currency': {'code': 'DKK', 'symbol': 'Dkr', 'name': 'Danish Krone'}},
#   {'name': 'OMX Stockholm 30',
#    'symbol': 'OMXS30.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Sweden',
#    'currency': {'code': 'SEK', 'symbol': 'Skr', 'name': 'Swedish Krona'}},
#   {'name': 'ARCA Technology 100',
#    'symbol': 'PSE.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'THE PHILIPPINE STOCK EXC PSEI INDEX',
#    'symbol': 'PSEI.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Philippines',
#    'currency': {'code': 'PHP', 'symbol': '₱', 'name': 'Philippine Peso'}},
#   {'name': 'PSI 20 Stock Index',
#    'symbol': 'PSI20.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Portugal',
#    'currency': {'code': 'EUR', 'symbol': '€', 'name': 'Euro'}},
#   {'name': 'DOW JONES EQUITY ALL REIT TOTAL RETURN INDEX',
#    'symbol': 'REIT.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Australia',
#    'currency': {'code': 'AUD', 'symbol': 'A$', 'name': 'Australian Dollar'}},
#   {'name': 'RTSI Index (Russia)',
#    'symbol': 'RTSI.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Russia',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'S&P GLOBAL 1200',
#    'symbol': 'SGLY.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'Swiss Mid Price',
#    'symbol': 'SMIM.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Switzerland',
#    'currency': {'code': 'CHF', 'symbol': 'CHF', 'name': 'Swiss Franc'}},
#   {'name': 'Philadelphia Semiconductor Index',
#    'symbol': 'SOX.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'S&P 100 Index',
#    'symbol': 'SP100.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'S&P 500 ',
#    'symbol': 'SP500NTR.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'FTSE MIB IDX',
#    'symbol': 'SPMIB.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Italy',
#    'currency': {'code': 'EUR', 'symbol': '€', 'name': 'Euro'}},
#   {'name': 'S&P Preferred Stock Index',
#    'symbol': 'SPPREF.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'Shanghai Composite',
#    'symbol': 'SSEC.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'China',
#    'currency': {'code': 'CNY', 'symbol': 'CN¥', 'name': 'Chinese Yuan'}},
#   {'name': 'Swiss Market Index',
#    'symbol': 'SSMI.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Switzerland',
#    'currency': {'code': 'CHF', 'symbol': 'CHF', 'name': 'Swiss Franc'}},
#   {'name': 'SZSE Composite',
#    'symbol': 'SZSC.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'China',
#    'currency': {'code': 'CNY', 'symbol': 'CN¥', 'name': 'Chinese Yuan'}},
#   {'name': 'Tel Aviv 100 Index',
#    'symbol': 'TA100.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Israel',
#    'currency': {'code': 'ILS', 'symbol': '₪', 'name': 'Israeli New Sheqel'}},
#   {'name': 'Tel Aviv 35 Index',
#    'symbol': 'TA35.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Israel',
#    'currency': {'code': 'ILS', 'symbol': '₪', 'name': 'Israeli New Sheqel'}},
#   {'name': 'Tadawul All Share',
#    'symbol': 'TASI.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Saudi Arabia',
#    'currency': {'code': 'SAR', 'symbol': 'SR', 'name': 'Saudi Riyal'}},
#   {'name': 'CBOE Interest Rate 10-Year T-Note  Index',
#    'symbol': 'TNX.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'Taiwan Weighted',
#    'symbol': 'TWII.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Taiwan',
#    'currency': {'code': 'TWD', 'symbol': 'NT$', 'name': 'New Taiwan Dollar'}},
#   {'name': 'Dow Jones 30 Futures',
#    'symbol': 'US30.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'S&P 500 Futures',
#    'symbol': 'US500.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'CBOE Volatility Index',
#    'symbol': 'VIX.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'CBOE Vix Volatility',
#    'symbol': 'VVIX.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'S&P 500 VIX Futures',
#    'symbol': 'VX.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'DJIA Volatility',
#    'symbol': 'VXD.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'WSE WIG INDEX',
#    'symbol': 'WIG.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Poland',
#    'currency': {'code': 'PLN', 'symbol': 'zł', 'name': 'Polish Zloty'}},
#   {'name': 'Philadelphia Gold/Silver',
#    'symbol': 'XAU.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'NYSE AMEX Composite',
#    'symbol': 'XAX.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'ARCA Computer Technology',
#    'symbol': 'XCI.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'ARCA Major Markets',
#    'symbol': 'XMI.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'ARCA Oil',
#    'symbol': 'XOI.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'USA',
#    'currency': {'code': 'USD', 'symbol': '$', 'name': 'US Dollar'}},
#   {'name': 'BIST 100',
#    'symbol': 'XU100.INDX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': 'Turkey',
#    'currency': {'code': 'TRY', 'symbol': 'TL', 'name': 'Turkish Lira'}}]}

# %%
column_list = ['date', 'sp500_adj_closing']
sp500_df = pd.DataFrame(columns=column_list)

for dict in sp_list: 
    for list in dict: 
        if list == "date":
            temp_date = str(dateutil.parser.parse(dict[list]).date())
            #print(temp_date)
        elif list == "adj_close":
            temp_close = dict[list] 
            
    new_row = {'date':temp_date, 'sp500_adj_closing':temp_close}
    sp500_df = sp500_df.append(new_row, ignore_index=True)                 
    
    
print(sp500_df)
# Out:
#             date  sp500_adj_closing
# 0     2020-11-02          3310.2400
# 1     2020-10-30          3269.9600
# 2     2020-10-29          3310.1101
# 3     2020-10-28          3271.0300
# 4     2020-10-27          3390.6799
# ...          ...                ...
# 2511  2010-11-09          1213.4000
# 2512  2010-11-08          1223.2500
# 2513  2010-11-05          1225.8500
# 2514  2010-11-04          1221.0601
# 2515  2010-11-03          1197.9600
#
# [2516 rows x 2 columns]
